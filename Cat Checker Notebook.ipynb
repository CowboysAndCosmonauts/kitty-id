# %%
import numpy as np
import h5py
from data_helpers import * 
from Network import Network
import imageio

import scipy
from skimage import transform,io

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
train_set_x, train_set_y, test_set_x, test_set_y, classes = load_data()

# %%
layer_sizes = [12288, 20, 7, 5, 1]

# %%
N = Network(layer_sizes)
model = N.train(train_set_x, train_set_y, print_cost=True)
# Out:
# Cost after iteration 0: 0.662899
# Cost after iteration 100: 0.538074
# Cost after iteration 200: 0.479431
# Cost after iteration 300: 0.416247
# Cost after iteration 400: 0.348318
# Cost after iteration 500: 0.333259
# Cost after iteration 600: 0.155093
# Cost after iteration 700: 0.100200
# Cost after iteration 800: 0.058222
# Cost after iteration 900: 0.036450
# Cost after iteration 1000: 0.025628
# Cost after iteration 1100: 0.019039
# Cost after iteration 1200: 0.014768
# Cost after iteration 1300: 0.011881
# Cost after iteration 1400: 0.009823
# Cost after iteration 1500: 0.008278
# Cost after iteration 1600: 0.007100
# Cost after iteration 1700: 0.006193
# Cost after iteration 1800: 0.005459
# Cost after iteration 1900: 0.004858
# Cost after iteration 2000: 0.004364
# Cost after iteration 2100: 0.003944
# Cost after iteration 2200: 0.003590
# Cost after iteration 2300: 0.003281
# Cost after iteration 2400: 0.003016
# Cost after iteration 2500: 0.002790
# Cost after iteration 2600: 0.002596
# Cost after iteration 2700: 0.002421
# Cost after iteration 2800: 0.002267
# Cost after iteration 2900: 0.002130

# %%
train_accuracy = N.predict(train_set_x, train_set_y, model)
# Out:
# Accuracy: 0.9999999999999998

# %%
test_accuracy = N.predict(test_set_x, test_set_y, model)
# Out:
# Accuracy: 0.74

# %%
my_image = "levi_2_resize.jpg" 
my_label_y = [1] # (1 -> cat, 0 -> non-cat)

fname = "images/" + my_image
image = np.array(imageio.imread(fname))

my_image_flatten = image.reshape(64*64*3, 1)


my_image = my_image_flatten/255.


my_predicted_image = N.predict(my_image, my_label_y, model)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# Accuracy: 1.0
# y = 1.0, your L-layer model predicts a "cat" picture.

# %%
print_mislabeled_images(classes, test_set_x, test_set_y, test_accuracy)
