# %%
import numpy as np
import h5py
from data_helpers import * 
from Network import Network
import imageio

import scipy
from skimage import transform,io

import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (5.0, 4.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
train_set_x, train_set_y, test_set_x, test_set_y, classes = load_data()

# %%
layer_sizes = [12288, 20, 7, 5, 1]

# %%
N = Network(layer_sizes)
model = N.train(train_set_x, train_set_y, print_cost=True)
# Out:
# Cost after iteration 0: 0.701167
# Cost after iteration 100: 0.674000
# Cost after iteration 200: 0.658972
# Cost after iteration 300: 0.643738
# Cost after iteration 400: 0.627597
# Cost after iteration 500: 0.607941
# Cost after iteration 600: 0.579842
# Cost after iteration 700: 0.545881
# Cost after iteration 800: 0.503754
# Cost after iteration 900: 0.470686
# Cost after iteration 1000: 0.452455
# Cost after iteration 1100: 0.398857
# Cost after iteration 1200: 0.384668
# Cost after iteration 1300: 0.307748
# Cost after iteration 1400: 0.300038
# Cost after iteration 1500: 0.183283
# Cost after iteration 1600: 0.078368
# Cost after iteration 1700: 0.057784
# Cost after iteration 1800: 0.043809
# Cost after iteration 1900: 0.035684
# Cost after iteration 2000: 0.030371
# Cost after iteration 2100: 0.026543
# Cost after iteration 2200: 0.023583
# Cost after iteration 2300: 0.021183
# Cost after iteration 2400: 0.019139
# Cost after iteration 2500: 0.017347
# Cost after iteration 2600: 0.015724
# Cost after iteration 2700: 0.014311
# Cost after iteration 2800: 0.013379
# Cost after iteration 2900: 0.012560

# %%
train_accuracy = N.predict(train_set_x, train_set_y, model)
# Out:
# Accuracy: 0.9952153110047844

# %%
test_accuracy = N.predict(test_set_x, test_set_y, model)
# Out:
# Accuracy: 0.74

# %%
my_image = "dog_resize.jpg" 
my_label_y = [0] # (1 -> cat, 0 -> non-cat)

fname = "images/" + my_image
image = np.array(imageio.imread(fname))

my_image_flatten = image.reshape(64*64*3, 1)


my_image = my_image_flatten/255.


my_predicted_image = N.predict(my_image, my_label_y, model)

plt.imshow(image)
print ("y = " + str(np.squeeze(my_predicted_image)) + ", your L-layer model predicts a \"" + classes[int(np.squeeze(my_predicted_image)),].decode("utf-8") +  "\" picture.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-02781fd927ff> in <module>
#      11
#      12
# ---> 13 my_predicted_image = N.predict(my_image, my_label_y, model)
#      14
#      15 plt.imshow(image)
#
# NameError: name 'N' is not defined

# %%
print_mislabeled_images(classes, test_set_x, test_set_y, test_accuracy)
